# %%
import matplotlib.pyplot as plt
x=["a","b","d"]
y=[120,119,5,]
# plt.ylable("marks")
plt.title("details in INDIA",fontsize=20)
plt.ylabel("marks in BTech in ")
plt.xlabel("kitna  in one month")

plt.bar(x,y,color="g",edgecolor="b",width=0.5,label="i am  st art")
plt.legend()
plt.show()
# import pip
# pip.main(["install","matplotlib"])

# %%
import matplotlib.pyplot as plt
x=[2,3,4,5,6,7,4,3,5,4,300,4,5,5,6,50,5,5,6,0.0006,]
y=[43+j for j in x]
plt.scatter(x,y)
plt.title("Scatter Learning series")
plt
plt.show()

# print(x.length())

# %%
import matplotlib.pyplot as plt
x=[2,3,4,]
y=[j+j for j in x]
# sizes=[400,400,500]
colors=["b","r","g"]
plt.scatter(x,y,c=colors,s=100000)
plt.title("Scatter Learning series")
plt
plt.show()

# print(x.length())
