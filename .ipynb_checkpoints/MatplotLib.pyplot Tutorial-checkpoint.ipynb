# %%
import matplotlib.pyplot as plt
x=["a","b","d"]
y=[120,119,5,]
# plt.ylable("marks")
plt.title("pornography in INDIA",fontsize=20)
plt.ylabel("marks in BTech in Pornology")
plt.xlabel("kitna hilaya in one month")

plt.bar(x,y,color="g",edgecolor="b",width=0.5,label="i am porn st art")
plt.legend()
plt.show()
# import pip
# pip.main(["install","matplotlib"])

# %%
r=[6,55,4,6,55,4,6,55,4,6,55,4,6,55,4,6,55,4,    ]
p=[145+j for j in r]
print(p)
# Out:
# [151, 200, 149, 151, 200, 149, 151, 200, 149, 151, 200, 149, 151, 200, 149, 151, 200, 149]
